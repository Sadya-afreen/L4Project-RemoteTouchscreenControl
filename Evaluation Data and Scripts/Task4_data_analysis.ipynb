# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task4Data_Final.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "template.tx", "final.tx", "template.ty","final.ty","Start Time","End Time"])
data = data.groupby(['Participant', 'Condition'], as_index=False).agg({'timems': 'mean'})
tr  = data.loc[data['Condition'] == 'Smart Trackpad']
tb  = data.loc[data['Condition'] == 'Smart Trackball']
tp = data.loc[data['Condition'] == 'Smart Tilt Pointer']
rp = data.loc[data['Condition'] == 'Smart Rotate Pointer']

plot, axis = plt.subplots(figsize=(8, 4))
sns.distplot(tr['timems'],  hist=False, label="Trackpad",        color="orange")
sns.distplot(tb['timems'],  hist=False, label="Trackball",         color="red")
sns.distplot(tp['timems'], hist=False, label="Tilt Pointer", color="teal")
sns.distplot(rp['timems'], hist=False, label="Rotate Pointer", color="blue")
axis.set_xlabel("Time (ms)")
axis.set_ylabel("Density")
axis.legend()
plot.show()
# Out:
# C:\Users\sadya\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sadya\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task4Data_Final.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "template.tx", "final.tx", "template.ty","final.ty","Start Time","End Time"])
data = data.groupby(['Participant','Condition'], as_index=False).agg({'timems': 'mean'})
#data=data.loc[data['Condition']]
#print(data)
tr  = data.loc[data['Condition'] == 'Smart Trackpad']
tb  = data.loc[data['Condition'] == 'Smart Trackball']
tp = data.loc[data['Condition'] == 'Smart Tilt Pointer']
rp = data.loc[data['Condition'] == 'Smart Rotate Pointer']

plot, axis = plt.subplots(figsize=(8, 4))
axis.set_title("Mean Task Time")
sns.barplot(x="Condition", y="timems",data=data,errcolor = 'black', errwidth = 2,capsize=0.25,ci=95,color=sns.set_palette("ocean_r") )
axis.set_xlabel("Technique")
axis.set_ylabel("Time (ms)")
#plot.show()
# Out:
# Text(0, 0.5, 'Time (ms)')

# %%
# import matplotlib.pyplot as plt
# import pandas as pd
# import pingouin as pg
# import seaborn as sns

# # Read experiment data into a data frame
# data = pd.read_csv("P1-15Task4Data_Final.csv")

# # Get rid of excess columns - we don't need these for this analysis
# data = data.drop(columns=["Block","Task","Start Time","End Time"])
# data = data.groupby(['Participant','Condition'], as_index=False).agg({'timems': 'mean'})
# #data=data.loc[data['Condition']]
# #print(data)
# tr  = data.loc[data['Condition'] == 'Smart Trackpad']
# tb  = data.loc[data['Condition'] == 'Smart Trackball']
# tp = data.loc[data['Condition'] == 'Smart Tilt Pointer']
# rp = data.loc[data['Condition'] == 'Smart Rotate Pointer']

# plot, axis = plt.subplots(figsize=(10, 5))
# sns.barplot(x="Condition", y="timems",data=data,errcolor = 'black', errwidth = 2,capsize=0.25,ci=95 )
#plot.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task4Data_Final.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task","template.ty","final.ty","Start Time","End Time"])
data = data.groupby(['Participant', 'Condition',"template.tx", "final.tx"], as_index=False).agg({'txdiff':'mean','tydiff':'mean'})
tr  = data.loc[data['Condition'] == 'Smart Trackpad']
tb  = data.loc[data['Condition'] == 'Smart Trackball']
tp = data.loc[data['Condition'] == 'Smart Tilt Pointer']
rp = data.loc[data['Condition'] == 'Smart Rotate Pointer']
#print(tr)
plot, axis = plt.subplots(figsize=(8, 4))
#print(axis.size)
#sns.distplot(abs(tr['final1.tx']-tr['template1.tx']),  hist=False, label="Trackpad",        color="orange")
#sns.distplot(abs(tb['final1.tx']-tb['template1.tx']),  hist=False, label="Trackball",         color="red")
#sns.distplot(abs(tp['final1.tx']-tp['template1.tx']), hist=False, label="Tilt Pointer", color="teal")
#sns.distplot(abs(rp['final1.tx']-rp['template1.tx']), hist=False, label="Rotate Pointer", color="blue")
axis = sns.distplot(abs(tr['txdiff']),  hist=False, label="Trackpad",        color="red")
axis =sns.distplot(abs(tb['txdiff']),  hist=False, label="Trackball",         color="green")
axis =sns.distplot(abs(tp['txdiff']), hist=False, label="Tilt Pointer", color="orange")
axis =sns.distplot(abs(rp['txdiff']), hist=False, label="Rotate Pointer", color="blue")
axis.set_xlabel("Horizontal Error")
axis.set_ylabel("Density")
axis.legend()

plot1, axis1 = plt.subplots(figsize=(8, 4))
axis1 = sns.distplot(abs(tr['tydiff']),  hist=False, label="Trackpad",        color="red")
axis1 =sns.distplot(abs(tb['tydiff']),  hist=False, label="Trackball",         color="green")
axis1 =sns.distplot(abs(tp['tydiff']), hist=False, label="Tilt Pointer", color="orange")
axis1 =sns.distplot(abs(rp['tydiff']), hist=False, label="Rotate Pointer", color="blue")
axis1.set_xlabel("Vertical Error")
axis1.set_ylabel("Density")
axis1.legend()
#plot.show()
# Out:
# C:\Users\sadya\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sadya\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#!pip install -U seaborn
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns
import numpy as np
# Read experiment data into a data frame
data = pd.read_csv("P1-15Task4Data_Final.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task"])
data = data.groupby(['Participant', 'Condition','txdiff','tydiff'], as_index=False).agg({'timems':'mean'})
tr  = data.loc[data['Condition'] == 'Smart Trackpad']
tb  = data.loc[data['Condition'] == 'Smart Trackball']
tp = data.loc[data['Condition'] == 'Smart Tilt Pointer']
rp = data.loc[data['Condition'] == 'Smart Rotate Pointer']

final_tr=tr.groupby(['Participant'],as_index=False).agg({'txdiff':'sum'})

# g = sns.FacetGrid(tr, col="Condition")
# g.map(sns.histplot, "txdiff")
# g.map(sns.histplot, "tydiff")
plot, axis = plt.subplots(4,2,figsize=(15,15))
plt.subplots_adjust(hspace=0.4, wspace=0.14)
axis[0,0].hist(data=tr,x='txdiff',color='red',density=True)
axis[0,0].set_title("Smart Trackpad Technique - X Error")
axis[0,0].set_ylabel("Density")
axis[0,0].set_xlabel("Horizontal Error")
axis[0,1].hist(data=tr,x='tydiff',color='red',density=True)
axis[0,1].set_title("Smart Trackpad Technique - Y Error")
axis[0,1].set_ylabel("Density")
axis[0,1].set_xlabel("Vertical Error")

axis[1,0].hist(data=tb,x='txdiff',color='lightgreen',density=True)
axis[1,0].set_title("Smart Trackball Technique - X Error")
axis[1,0].set_ylabel("Density")
axis[1,0].set_xlabel("Horizontal Error")
axis[1,1].hist(data=tb,x='tydiff',color='lightgreen',density=True)
axis[1,1].set_title("Smart Trackball Technique - Y Error")
axis[1,1].set_ylabel("Density")
axis[1,1].set_xlabel("Vertical Error")

axis[2,0].hist(data=tp,x='txdiff',color='orange',density=True)
axis[2,0].set_title("Smart Tilt Technique - X Error")
axis[2,0].set_ylabel("Density")
axis[2,0].set_xlabel("Horizontal Error")
axis[2,1].hist(data=tp,x='tydiff',color='orange',density=True)
axis[2,1].set_title("Smart Tilt Technique - Y Error")
axis[2,1].set_ylabel("Density")
axis[2,1].set_xlabel("Vertical Error")

axis[3,0].hist(data=rp,x='txdiff',color='skyblue',density=True)
axis[3,0].set_title("Smart Rotate Technique - X Error")
axis[3,0].set_ylabel("Density")
axis[3,0].set_xlabel("Horizontal Error")
axis[3,1].hist(data=rp,x='tydiff',color='skyblue',density=True)
axis[3,1].set_title("Smart Rotate Technique - Y Error")
axis[3,1].set_ylabel("Density")
axis[3,1].set_xlabel("Vertical Error")
#sns.distplot(abs(tr['final1.tx']-tr['template1.tx']),  hist=False, label="Trackpad",        color="orange")
#sns.distplot(abs(tb['final1.tx']-tb['template1.tx']),  hist=False, label="Trackball",         color="red")
#sns.distplot(abs(tp['final1.tx']-tp['template1.tx']), hist=False, label="Tilt Pointer", color="teal")
#sns.distplot(abs(rp['final1.tx']-rp['template1.tx']), hist=False, label="Rotate Pointer", color="blue")
#sns.distplot( abs(final_tr['txdiff']), hist=True, label="Trackpad",        color="orange")
# sns.histplot(data = tr, x='txdiff', color="blue")
# plot1, axis1 = plt.subplots(figsize=(8,5))
# sns.histplot(data = tb, x='txdiff', color="blue")
# sns.distplot(abs(tp['txdiff']), hist=False, label="Tilt Pointer", color="teal")
# sns.distplot(abs(rp['txdiff']), hist=False, label="Rotate Pointer", color="blue")
#axis.hist(abs(tr['txdiff']),bins=tr['Participant'],density = False)

#plot.show()
# Out:
# Text(0.5, 0, 'Vertical Error')

# %%
# import matplotlib.pyplot as plt
# #import matplotlib.pyplot as plt2
# import pandas as pd
# import pingouin as pg
# import seaborn as sns
# import numpy as np
# # Read experiment data into a data frame
# data = pd.read_csv("P1-15Task4Data.csv")

# # Get rid of excess columns - we don't need these for this analysis


# data = data.drop(columns=["Block","Task","Start Time","End Time"])

# data = data.groupby(['Participant','Condition'], as_index=False).agg({'Euclidean_distance_error1': 'mean','Euclidean_distance_error2':'mean'})
# #data=data.loc[data['Condition']]
# #print(data)
# tr  = data.loc[data['Condition'] == 'Smart Trackpad']
# tb  = data.loc[data['Condition'] == 'Smart Trackball']
# tp = data.loc[data['Condition'] == 'Smart Tilt Pointer']
# rp = data.loc[data['Condition'] == 'Smart Rotate Pointer']

# plot, axis = plt.subplots(1,2,figsize=(25, 5))
# sns.barplot(ax=axis[0],x="Condition", y="Euclidean_distance_error1",data=data,errcolor = 'black', errwidth = 2,capsize=0.25,ci=95 )
# axis[0].set_title("Mean distance for trial 1")
# axis[0].set_xlabel("Technique")
# axis[0].set_ylabel("Mean distance")

# sns.barplot(ax=axis[1],x="Condition", y="Euclidean_distance_error2",data=data,errcolor = 'black', errwidth = 2,capsize=0.25,ci=95 )
# axis[1].set_title("Mean distance for trial 2")
# axis[1].set_xlabel("Technique")
# axis[1].set_ylabel("Mean distance")

# %%
import matplotlib.pyplot as plt
#import matplotlib.pyplot as plt2
import pandas as pd
import pingouin as pg
import seaborn as sns
import numpy as np
# Read experiment data into a data frame
data = pd.read_csv("P1-15Task4Data_Final.csv")

# Get rid of excess columns - we don't need these for this analysis


data = data.drop(columns=["Block","Task","Start Time","End Time"])

data = data.groupby(['Participant','Condition'], as_index=False).agg({'Euclidean_distance_error': 'mean'})
#data=data.loc[data['Condition']]
#print(data)
tr  = data.loc[data['Condition'] == 'Smart Trackpad']
tb  = data.loc[data['Condition'] == 'Smart Trackball']
tp = data.loc[data['Condition'] == 'Smart Tilt Pointer']
rp = data.loc[data['Condition'] == 'Smart Rotate Pointer']

plot, axis = plt.subplots(figsize=(8, 4))
sns.barplot(x="Condition", y="Euclidean_distance_error",data=data,errcolor = 'black', errwidth = 2,capsize=0.25,ci=95 )
axis.set_title("Mean Euclidean distance")
axis.set_xlabel("Technique")
axis.set_ylabel("Distance")

# sns.barplot(ax=axis[1],x="Condition", y="Euclidean_distance_error2",data=data,errcolor = 'black', errwidth = 2,capsize=0.25,ci=95 )
# axis[1].set_title("Mean distance for trial 2")
# axis[1].set_xlabel("Technique")
# axis[1].set_ylabel("Mean distance")
# Out:
# Text(0, 0.5, 'Distance')

# %% [markdown]
# ANOVA TEST FOR TIME

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task4Data_Final.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task"])
data = data.groupby(['Participant', 'Condition'], as_index=False).agg({'timems': 'mean'})
aov_time = pg.rm_anova(dv='timems', within='Condition', subject='Participant', data=data)
pg.print_table(aov_time)
# Out:
# ...
# ANOVA SUMMARY
# ...
#
# Source       ddof1    ddof2      F    p-unc    p-GG-corr    np2    eps  sphericity      W-spher    p-spher
# ---------  -------  -------  -----  -------  -----------  -----  -----  ------------  ---------  ---------
# Condition        3       42  3.358    0.028        0.050  0.193  0.662  False             0.392      0.037

# %% [markdown]
# T-Test for Time

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task4Data_Final.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "template.tx", "final.tx", "template.ty","final.ty","Start Time","End Time"])
data = data.groupby(['Participant', 'Condition'], as_index=False).agg({'timems': 'mean'})
ph_time = pg.pairwise_ttests(dv='timems', within='Condition', subject='Participant', data=data)
pg.print_table(ph_time)
# Out:
# ...
# POST HOC TESTS
# ...
#
# Contrast    A                     B                   Paired    Parametric         T     dof  Tail         p-unc    BF10    hedges
# ----------  --------------------  ------------------  --------  ------------  ------  ------  ---------  -------  ------  --------
# Condition   Smart Rotate Pointer  Smart Tilt Pointer  True      True           1.103  14.000  two-sided    0.289   0.441     0.239
# Condition   Smart Rotate Pointer  Smart Trackball     True      True           3.377  14.000  two-sided    0.005  10.768     1.031
# Condition   Smart Rotate Pointer  Smart Trackpad      True      True           1.260  14.000  two-sided    0.228   0.512     0.384
# Condition   Smart Tilt Pointer    Smart Trackball     True      True           3.402  14.000  two-sided    0.004  11.242     0.823
# Condition   Smart Tilt Pointer    Smart Trackpad      True      True           0.738  14.000  two-sided    0.473   0.333     0.223
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task4Data_Final.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task","Start Time","End Time","Difftime"])
data = data.groupby(['Participant', 'Condition'], as_index=False).agg({'Euclidean_distance_error': 'mean'})
aov_time = pg.rm_anova(dv='Euclidean_distance_error', within='Condition', subject='Participant', data=data)
pg.print_table(aov_time)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-099d2448f859> in <module>
#       8
#       9 # Get rid of excess columns - we don't need these for this analysis
# ---> 10 data = data.drop(columns=["Block","Task","Start Time","End Time","Difftime"])
#      11 data = data.groupby(['Participant', 'Condition'], as_index=False).agg({'Euclidean_distance_error': 'mean'})
#      12 aov_time = pg.rm_anova(dv='Euclidean_distance_error', within='Condition', subject='Participant', data=data)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task4Data_Final.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task","Start Time","End Time","Difftime"])
data = data.groupby(['Participant', 'Condition'], as_index=False).agg({'Euclidean_distance_error': 'mean'})
ph_time = pg.pairwise_ttests(dv='Euclidean_distance_error', within='Condition', subject='Participant', data=data)
pg.print_table(ph_time)
# Out:
# ...
# POST HOC TESTS
# ...
#
# Contrast    A                     B                   Paired    Parametric         T     dof  Tail         p-unc    BF10    hedges
# ----------  --------------------  ------------------  --------  ------------  ------  ------  ---------  -------  ------  --------
# Condition   Smart Rotate Pointer  Smart Tilt Pointer  True      True           2.733  14.000  two-sided    0.016   3.760     0.910
# Condition   Smart Rotate Pointer  Smart Trackball     True      True           2.355  14.000  two-sided    0.034   2.095     0.812
# Condition   Smart Rotate Pointer  Smart Trackpad      True      True           1.884  14.000  two-sided    0.081   1.070     0.633
# Condition   Smart Tilt Pointer    Smart Trackball     True      True          -0.174  14.000  two-sided    0.865   0.266    -0.063
# Condition   Smart Tilt Pointer    Smart Trackpad      True      True          -1.206  14.000  two-sided    0.248   0.485    -0.374
# ...
