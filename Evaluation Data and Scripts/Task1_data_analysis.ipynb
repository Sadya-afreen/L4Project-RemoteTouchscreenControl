# %%
# import matplotlib.pyplot as plt
# import pandas as pd
# import pingouin as pg
# import seaborn as sns

# # Read experiment data into a data frame
# data = pd.read_csv("P1-15Task1Data.csv")

# # Get rid of excess columns - we don't need these for this analysis
# data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l","Target Area","MousePositions.x",
#                          "MousePositions.y","Error.x","Error.y"])
# data = data.groupby(['Participant','Condition'], as_index=False).agg({'Target_count':'sum'})
# #print(data)
# tr  = data.loc[data['Condition'] == 'Smart Trackpad']
# tb  = data.loc[data['Condition'] == 'Smart Trackball']
# tp = data.loc[data['Condition'] == 'Smart Tilt Pointer']
# rp = data.loc[data['Condition'] == 'Smart Rotate Pointer']
# #print(tr)
# plot, axis = plt.subplots(figsize=(8, 4))
# axis.set_title("Number of targets selected")
# sns.barplot(y='Target_count',x='Condition',data=data,errcolor = 'black', errwidth = 2,capsize=0.25,ci=95)
# # sns.barplot(y='Trial',x='Condition',data=data,label="Trackball",         color="red")
# # sns.barplot(y='Trial',x='Condition',data=data,label="Tilt Pointer", color="teal")
# # sns.barplot(y=rp['Trial'], label="Rotate Pointer", color="blue")
# axis.set_xlabel("Time (ms)")
# axis.set_ylabel("Count")
#axis.legend()

# %%
##!pip install pingouin
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l","Target Area","MousePositions.x",
                         "MousePositions.y","Error.x","Error.y"])
data = data.groupby(['Participant','Condition'], as_index=False).count()
#print(data)
tr  = data.loc[data['Condition'] == 'Smart Trackpad']
tb  = data.loc[data['Condition'] == 'Smart Trackball']
tp = data.loc[data['Condition'] == 'Smart Tilt Pointer']
rp = data.loc[data['Condition'] == 'Smart Rotate Pointer']
#print(tr)
plot, axis = plt.subplots(figsize=(8, 4))
axis.set_title("Number of targets selected")
sns.barplot(y='Trial',x='Condition',data=data,errcolor = 'black', errwidth = 2,capsize=0.25,ci=95)
# sns.barplot(y='Trial',x='Condition',data=data,label="Trackball",         color="red")
# sns.barplot(y='Trial',x='Condition',data=data,label="Tilt Pointer", color="teal")
# sns.barplot(y=rp['Trial'], label="Rotate Pointer", color="blue")
axis.set_xlabel("Technique")
axis.set_ylabel("Count")
#axis.legend()
# Out:
# Text(0, 0.5, 'Count')

# %%
##!pip install pingouin
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l","Target Area","MousePositions.x",
                         "MousePositions.y"])
data = data.groupby(['Participant','Condition'], as_index=False).agg({"Error_count":'mean'})

plot, axis = plt.subplots(figsize=(8, 4))
axis.set_title("Mean error count")
sns.barplot(y='Error_count',x='Condition',data=data,errcolor = 'black', errwidth = 2,capsize=0.25,ci=95,color=sns.set_palette("ocean_r"))
axis.set_xlabel("Technique")
axis.set_ylabel("Mean Error")
#axis.legend()
# Out:
# Text(0, 0.5, 'Mean Error')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l","Target Area","MousePositions.x",
                         "MousePositions.y"])
data = data.groupby(['Condition','Error.x','Error.y'], as_index=False).agg({'Trial':'mean'})
#print(data)
data_error=data.loc[data['Error.x']>0]
#print(data_error.count())
data_error = data_error.groupby(['Condition','Error.x']).count()
#print(data_error.count())
#print(data['Error.x']>0)
tr  = data.loc[data['Condition'] == 'Smart Trackpad']
tb  = data.loc[data['Condition'] == 'Smart Trackball']
tp = data.loc[data['Condition'] == 'Smart Tilt Pointer']
rp = data.loc[data['Condition'] == 'Smart Rotate Pointer']

tr_error=tr.loc[tr['Error.x']>0]
tb_error=tb.loc[tb['Error.x']>0]
tp_error=tp.loc[tp['Error.x']>0]
rp_error=rp.loc[rp['Error.x']>0]
total_error_count = [42,32,54,55]
condition = ["Smart Rotate Pointer","Smart Tilt Pointer","Smart Trackball","Smart Trackpad"]
c=['lightblue','orange','green','red']
plot, axis = plt.subplots(figsize=(8, 4))
x=tb['Condition']
axis.set_title("Number of errors detected")
axis.bar(condition, total_error_count,width=0.5)
# sns.plot(y=tp_error.count(),x=tp['Condition'],data=data)
# sns.plot(y=rp_error.count(),x=rp['Condition'],data=data)
#sns.barplot(y='Error.x',x=condition,data=data_error)
# sns.barplot(y='Trial',x='Condition',data=data,label="Tilt Pointer", color="teal")
# sns.barplot(y=rp['Trial'], label="Rotate Pointer", color="blue")
axis.set_xlabel("Technique")
axis.set_ylabel("Error Count")
#axis.legend()
# Out:
# Text(0, 0.5, 'Error Count')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l","Target Area","MousePositions.x",
                         "MousePositions.y","Error.x","Error.y"])
data = data.groupby(['Participant','Condition'], as_index=False).agg({'Euclidean_distance_error':'mean'})

tr  = data.loc[data['Condition'] == 'Smart Trackpad']
tb  = data.loc[data['Condition'] == 'Smart Trackball']
tp = data.loc[data['Condition'] == 'Smart Tilt Pointer']
rp = data.loc[data['Condition'] == 'Smart Rotate Pointer']

plot, axis = plt.subplots(figsize=(8, 4))
axis.set_title("Mean Error Distance")
sns.distplot(tr['Euclidean_distance_error'],  hist=False, label="Trackpad",        color="orange")
sns.distplot(tb['Euclidean_distance_error'],  hist=False, label="Trackball",         color="red")
sns.distplot(tp['Euclidean_distance_error'], hist=False, label="Tilt Pointer", color="teal")
sns.distplot(rp['Euclidean_distance_error'], hist=False, label="Rotate Pointer", color="blue")
axis.set_xlabel("Mean Distance")
axis.set_ylabel("Density")
axis.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l","Target Area","MousePositions.x",
                         "MousePositions.y"])
data = data.groupby(['Participant','Condition'], as_index=False).agg({'Euclidean_distance_error':'mean'})

tr  = data.loc[data['Condition'] == 'Smart Trackpad']
tb  = data.loc[data['Condition'] == 'Smart Trackball']
tp = data.loc[data['Condition'] == 'Smart Tilt Pointer']
rp = data.loc[data['Condition'] == 'Smart Rotate Pointer']

plot, axis = plt.subplots(figsize=(8, 4))
# x=tb['Condition']
axis.set_title("Mean Euclidean Distance")
#axis.bar(condition, total_error_count,width=0.5,color=sns.color_palette("Reds_r"))
# axis.bar(y=tb_error.count(),data=data)
# sns.plot(y=tp_error.count(),x=tp['Condition'],data=data)
# sns.plot(y=rp_error.count(),x=rp['Condition'],data=data)
sns.barplot(x="Condition", y="Euclidean_distance_error",data=data,errcolor = 'black', errwidth = 2,capsize=0.25,ci=95)
# sns.barplot(y='Trial',x='Condition',data=data,label="Tilt Pointer", color="teal")
# sns.barplot(y=rp['Trial'], label="Rotate Pointer", color="blue")
axis.set_xlabel("Technique")
axis.set_ylabel("Mean Distance (px)")
#axis.legend()
# Out:
# Text(0, 0.5, 'Mean Distance (px)')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
# data = data.drop(columns=["Block","Task", "EulerA_Initial.tx", "EulerA_Initial.ty", "EulerA_Initial.tz","EulerA1.tx",
#                           "EulerA1.ty", "EulerA1.tz", "EulerA3.tx","EulerA3.ty","EulerA3.tz","Cube1AngleofRot","Cube3AngleofRot",
#                           "Start Time","End Time","Difftime"])
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l","Target Area"])
data = data.groupby(['Participant','Condition',"MousePositions.x",
                         "MousePositions.y","Error.x","Error.y"], as_index=False).agg({'Euclidean_distance_error':'mean'})
#print(data)
tr  = data.loc[(data['Condition'] == 'Smart Trackpad') & (data['Error.x']>0)]
tb  = data.loc[(data['Condition'] == 'Smart Trackball')  & (data['Error.x']>0)]
tp = data.loc[(data['Condition'] == 'Smart Tilt Pointer')  & (data['Error.x']>0)]
rp = data.loc[(data['Condition'] == 'Smart Rotate Pointer')  & (data['Error.x']>0)]
#print(tr)
plot, axis = plt.subplots(1,2,figsize=(15, 5))
axis[0].set_title("Smart Trackpad XY Contour plot")
# Basic 2D density plot
sns.set_style("white")
axis[0].axvline(0, color='black')
axis[0].axhline(0, color='black')
sns.kdeplot(tr["MousePositions.x"]-tr["Error.x"], tr["MousePositions.y"]-tr["Error.y"],ax=axis[0])
#sns.plt.show()
 
# Custom it with the same argument as 1D density plot
sns.kdeplot(tr["MousePositions.x"]-tr["Error.x"],tr["MousePositions.y"]-tr["Error.y"], cmap="Reds", shade=True, bw=.15,gridsize=200,common_grid=False,color=sns.set_palette("Greens_d"),space=0,ax=axis[0])
 
# Some features are characteristic of 2D: color palette and wether or not color the lowest range
sns.kdeplot(tr["MousePositions.x"]-tr["Error.x"],tr["MousePositions.y"]-tr["Error.y"],  cmap="Blues", shade=True, shade_lowest=True, gridsize=200,common_grid=False,color=sns.set_palette("Greens_d"),space=0,ax=axis[0])
#plt.x_axis("S")
axis[1].set_title("Smart Trackball XY Contour plot")
sns.set_style("white")
axis[1].axvline(0, color='black')
axis[1].axhline(0, color='black')
sns.kdeplot(tb["MousePositions.x"]-tb["Error.x"], tb["MousePositions.y"]-tb["Error.y"])
#sns.plt.show()
 
# Custom it with the same argument as 1D density plot
sns.kdeplot(tb["MousePositions.x"]-tb["Error.x"],tb["MousePositions.y"]-tb["Error.y"], cmap="Reds", shade=True, bw=.15,gridsize=200,common_grid=False,color=sns.set_palette("Greens_d"))
 
# Some featuresare characteristic of 2D: color palette and wether or not color the lowest range
sns.kdeplot(tb["MousePositions.x"]-tb["Error.x"],tb["MousePositions.y"]-tb["Error.y"],  cmap="Blues", shade=True, shade_lowest=True, gridsize=200,common_grid=False,color=sns.set_palette("Greens_d"))
#plt.x_axis(


#plot.show()

plot1, axis1 = plt.subplots(1,2,figsize=(15, 5))
axis1[0].set_title("Smart Tilt Pointer XY Contour plot")
sns.set_style("white")
axis1[0].axvline(0, color='black')
axis1[0].axhline(0, color='black')
sns.kdeplot(tp["MousePositions.x"]-tp["Error.x"], tp["MousePositions.y"]-tp["Error.y"])
#sns.plt.show()
 
# Custom it with the same argument as 1D density plot
sns.kdeplot(tp["MousePositions.x"]-tp["Error.x"],tp["MousePositions.y"]-tp["Error.y"], cmap="Reds", shade=True, bw=.15,gridsize=200,common_grid=False,color=sns.set_palette("Greens_d"),ax=axis1[0])
 
# Some featuresare characteristic of 2D: color palette and wether or not color the lowest range
sns.kdeplot(tp["MousePositions.x"]-tp["Error.x"],tp["MousePositions.y"]-tp["Error.y"],  cmap="Blues", shade=True, shade_lowest=True, gridsize=200,common_grid=False,color=sns.set_palette("Greens_d"),ax=axis1[0])
#plt.x_axis("S")

axis1[1].set_title("Smart Rotate Pointer XY Contour plot")
sns.set_style("white")
axis1[1].axvline(0, color='black')
axis1[1].axhline(0, color='black')
sns.kdeplot(rp["MousePositions.x"]-rp["Error.x"], rp["MousePositions.y"]-rp["Error.y"])
#sns.plt.show()
 
# Custom it with the same argument as 1D density plot
sns.kdeplot(rp["MousePositions.x"]-rp["Error.x"],rp["MousePositions.y"]-rp["Error.y"], cmap="Reds", shade=True, bw=.15,gridsize=200,common_grid=False,color=sns.set_palette("Greens_d"),ax=axis1[1])
 
# Some featuresare characteristic of 2D: color palette and wether or not color the lowest range
sns.kdeplot(rp["MousePositions.x"]-rp["Error.x"],rp["MousePositions.y"]-rp["Error.y"],  cmap="Blues", shade=True, shade_lowest=True, gridsize=200,common_grid=False,color=sns.set_palette("Greens_d"),ax=axis1[1])
#plot1.show()
# Out:
#      Participant       Condition  MousePositions.x  MousePositions.y  Error.x  \
# 34             1  Smart Trackpad               127               364       23
# 35             1  Smart Trackpad               148               347       17
# 36             1  Smart Trackpad               150               421       23
# 37             1  Smart Trackpad               155               257       54
# 38             1  Smart Trackpad               172               363       23
# 39             1  Smart Trackpad               280               418        5
# 40             1  Smart Trackpad               541               410       48
# 91             3  Smart Trackpad                 7                73       20
# 96             3  Smart Trackpad                39                32       35
# 100            3  Smart Trackpad                59                20       14
# 102            3  Smart Trackpad                64                62       25
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l","MousePositions.x",
                         "MousePositions.y"])
data = data.groupby(['Condition','Error.x','Error.y','Target Area'], as_index=False).agg({'Error_count':'mean'})
#print(data)
data_error=data.loc[(data['Target Area']>=6394.94401)]
print(data_error)
#data_error = data_error.groupby(['Condition','Error.x']).count()
#print(data_error)
#print(data['Error.x']>0)
tr  = data.loc[(data['Condition'] == 'Smart Trackpad') & (data['Error.x']>0) & (data['Target Area']<=6394.94401)]
tb  = data.loc[(data['Condition'] == 'Smart Trackball')& (data['Error.x']>0) & (data['Target Area']<=6394.94401)]
tp = data.loc[(data['Condition'] == 'Smart Tilt Pointer')& (data['Error.x']>0) & (data['Target Area']<=6394.94401)]
rp = data.loc[(data['Condition'] == 'Smart Rotate Pointer')& (data['Error.x']>0) & (data['Target Area']<=6394.94401)]

tr_bigT  = data.loc[(data['Condition'] == 'Smart Trackpad') & (data['Error.x']>0) & (data['Target Area']>=6394.94401)]
tb_bigT  = data.loc[(data['Condition'] == 'Smart Trackball')& (data['Error.x']>0) & (data['Target Area']>=6394.94401)]
tp_bigT = data.loc[(data['Condition'] == 'Smart Tilt Pointer')& (data['Error.x']>0) & (data['Target Area']>=6394.94401)]
rp_bigT = data.loc[(data['Condition'] == 'Smart Rotate Pointer')& (data['Error.x']>0) & (data['Target Area']>=6394.94401)]

print(rp_bigT.count())
# tr_error=tr.loc[tr['Error.x']>0]
# tb_error=tb.loc[tb['Error.x']>0]
# tp_error=tp.loc[tp['Error.x']>0]
# rp_error=rp.loc[rp['Error.x']>0]
# total_error_count = [42,32,54,55]
condition = ["Smart Rotate Pointer","Smart Tilt Pointer","Smart Trackball","Smart Trackpad"]
total_error_count=[25,24,37,36]
c=['lightblue','orange','green','red']

total_error_count_bigT=[19,8,18,19]

plot, axis = plt.subplots(1,2,figsize=(15, 6))
#x=tb['Condition']
axis[0].set_title("Number of errors detected for small sized targets")
axis[0].bar(condition, total_error_count,width=0.5)
axis[0].set_xlabel("Technique")
axis[0].set_ylabel("Error Count for small sized targets")
# axis.bar(y=tb_error.count(),data=data)
# sns.plot(y=tp_error.count(),x=tp['Condition'],data=data)
# sns.plot(y=rp_error.count(),x=rp['Condition'],data=data)
#sns.barplot(y='Error.x',x=condition,data=data_error)
#sns.barplot(y='Trial',x='Condition',data=data_error,label="Tilt Pointer", color="teal")
# sns.barplot(y=rp['Trial'], label="Rotate Pointer", color="blue")
axis[1].set_title("Number of errors detected for big sized targets")
axis[1].bar(condition, total_error_count_bigT,width=0.5)
axis[1].set_xlabel("Technique")
axis[1].set_ylabel("Error Count for big sized targets")
#axis.legend()
# Out:
#                 Condition  Error.x  Error.y  Target Area  Error_count
# 52   Smart Rotate Pointer      0.0      0.0       6468.0          0.0
# 53   Smart Rotate Pointer      0.0      0.0       6608.0          0.0
# 54   Smart Rotate Pointer      0.0      0.0       6612.0          0.0
# 55   Smart Rotate Pointer      0.0      0.0       6625.0          0.0
# 56   Smart Rotate Pointer      0.0      0.0       6700.0          0.0
# ..                    ...      ...      ...          ...          ...
# 721        Smart Trackpad    137.0    166.0      14835.0          1.0
# 725        Smart Trackpad    167.0    415.0       7440.0          1.0
# 726        Smart Trackpad    180.0    288.0      11570.0          1.0
# 730        Smart Trackpad    193.0    393.0       8750.0          1.0
# 737        Smart Trackpad    365.0    359.0      16000.0          1.0
#
# [327 rows x 5 columns]
# Condition      23
# Error.x        23
# Error.y        23
# Target Area    23
# Error_count    23
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l","MousePositions.x",
                         "MousePositions.y"])
data = data.groupby(['Participant','Condition','Target Area'], as_index=False).agg({'Error_count':'mean'})
#print(data)
data_error_B=data.loc[(data['Target Area']>6394.94401)]
data_error_S=data.loc[(data['Target Area']<=6394.94401)]
print(data_error_B)
plot, axis = plt.subplots(1,2,figsize=(17, 5))
axis[0].set_title("Mean Error for big sized targets")

sns.barplot(ax=axis[0],x="Condition", y="Error_count",data=data_error_B,errcolor = 'black', errwidth = 2,
            capsize=0.25,ci=95,order=["Smart Rotate Pointer","Smart Tilt Pointer","Smart Trackball","Smart Trackpad"])
axis[0].set_xlabel("Technique")
axis[0].set_ylabel("Mean Error for big sized targets")
axis[0].set_ylim(0,0.6)

axis[1].set_title("Mean Error for small sized targets")

sns.barplot(ax=axis[1],x="Condition", y="Error_count",data=data_error_S,errcolor = 'black', errwidth = 2,
            capsize=0.25,ci=95 )
axis[1].set_xlabel("Technique")
axis[1].set_ylabel("Mean Error for small sized targets")
# Out:
#      Participant           Condition  Target Area  Error_count
# 10           1.0  Smart Tilt Pointer       7353.0          0.0
# 11           1.0  Smart Tilt Pointer      11648.0          1.0
# 12           1.0  Smart Tilt Pointer      12296.0          1.0
# 19           1.0     Smart Trackball       6450.0          0.0
# 20           1.0     Smart Trackball       6622.0          0.0
# ..           ...                 ...          ...          ...
# 760         15.0      Smart Trackpad       8658.0          0.0
# 761         15.0      Smart Trackpad       9828.0          0.0
# 762         15.0      Smart Trackpad      12876.0          0.0
# 763         15.0      Smart Trackpad      13158.0          0.0
# 764         15.0      Smart Trackpad      16000.0          1.0
#
# [339 rows x 4 columns]
# Text(0, 0.5, 'Mean Error for small sized targets')

# %% [markdown]
# # ANOVA TEST

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l"])
data = data.groupby(['Participant', 'Condition'], as_index=False).agg({'Target_count': 'sum'})
aov_target_count = pg.rm_anova(dv='Target_count', within='Condition', subject='Participant', data=data)
pg.print_table(aov_target_count)
# Out:
# ...
# ANOVA SUMMARY
# ...
#
# Source       ddof1    ddof2       F    p-unc    np2    eps
# ---------  -------  -------  ------  -------  -----  -----
# Condition        3       42  11.593    0.000  0.453  0.854

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l"])
data = data.groupby(['Participant', 'Condition'], as_index=False).agg({'Error_count': 'mean'})
aov_error_count = pg.rm_anova(dv='Error_count', within='Condition', subject='Participant', data=data)
pg.print_table(aov_error_count)
# Out:
# ...
# ANOVA SUMMARY
# ...
#
# Source       ddof1    ddof2      F    p-unc    np2    eps
# ---------  -------  -------  -----  -------  -----  -----
# Condition        3       42  6.405    0.001  0.314  0.754

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l"])
data = data.groupby(['Participant', 'Condition'], as_index=False).agg({'Euclidean_distance_error': 'mean'})
aov_dist = pg.rm_anova(dv='Euclidean_distance_error', within='Condition', subject='Participant', data=data)
pg.print_table(aov_dist)
# Out:
# ...
# ANOVA SUMMARY
# ...
#
# Source       ddof1    ddof2      F    p-unc    p-GG-corr    np2    eps  sphericity      W-spher    p-spher
# ---------  -------  -------  -----  -------  -----------  -----  -----  ------------  ---------  ---------
# Condition        3       42  3.913    0.015        0.033  0.218  0.649  False             0.395      0.038

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l","MousePositions.x",
                         "MousePositions.y"])
data = data.groupby(['Participant','Condition','Target Area'], as_index=False).agg({'Error_count':'mean'})
#print(data)
data_error_B=data.loc[(data['Target Area']>6394.94401)]
data_error_S=data.loc[(data['Target Area']<=6394.94401)]
print(data_error_B)
aov_big_err = pg.rm_anova(dv='Error_count', within='Condition', subject='Participant', data=data_error_B)
pg.print_table(aov_big_err)

aov_small_err = pg.rm_anova(dv='Error_count', within='Condition', subject='Participant', data=data_error_S)
pg.print_table(aov_small_err)
# Out:
#      Participant           Condition  Target Area  Error_count
# 10           1.0  Smart Tilt Pointer       7353.0          0.0
# 11           1.0  Smart Tilt Pointer      11648.0          1.0
# 12           1.0  Smart Tilt Pointer      12296.0          1.0
# 19           1.0     Smart Trackball       6450.0          0.0
# 20           1.0     Smart Trackball       6622.0          0.0
# ..           ...                 ...          ...          ...
# 760         15.0      Smart Trackpad       8658.0          0.0
# 761         15.0      Smart Trackpad       9828.0          0.0
# 762         15.0      Smart Trackpad      12876.0          0.0
# 763         15.0      Smart Trackpad      13158.0          0.0
# 764         15.0      Smart Trackpad      16000.0          1.0
#
# [339 rows x 4 columns]
#
# ...
# ANOVA SUMMARY
# ...
#
# Source       ddof1    ddof2      F    p-unc    p-GG-corr    np2    eps  sphericity      W-spher    p-spher
# ...

# %% [markdown]
# # T - Test

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l"])
data = data.groupby(['Participant', 'Condition'], as_index=False).agg({'Target_count': 'sum'})
ph_target_count = pg.pairwise_ttests(dv='Target_count', within='Condition', subject='Participant', data=data)
pg.print_table(ph_target_count)
# Out:
# C:\Users\sadya\Anaconda3\lib\site-packages\outdated\utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.9, the latest is 0.3.10.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# ...
# POST HOC TESTS
# ...
#
# Contrast    A                     B                   Paired    Parametric         T     dof  Tail         p-unc     BF10    hedges
# ----------  --------------------  ------------------  --------  ------------  ------  ------  ---------  -------  -------  --------
# Condition   Smart Rotate Pointer  Smart Tilt Pointer  True      True           0.489  14.000  two-sided    0.633    0.291     0.138
# Condition   Smart Rotate Pointer  Smart Trackball     True      True          -4.098  14.000  two-sided    0.001   36.040    -0.981
# Condition   Smart Rotate Pointer  Smart Trackpad      True      True          -2.753  14.000  two-sided    0.016    3.880    -0.799
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l"])
data = data.groupby(['Participant', 'Condition'], as_index=False).agg({'Error_count': 'mean'})
ph_err_count = pg.pairwise_ttests(dv='Error_count', within='Condition', subject='Participant', data=data)
pg.print_table(ph_err_count)
# Out:
# ...
# POST HOC TESTS
# ...
#
# Contrast    A                     B                   Paired    Parametric         T     dof  Tail         p-unc    BF10    hedges
# ----------  --------------------  ------------------  --------  ------------  ------  ------  ---------  -------  ------  --------
# Condition   Smart Rotate Pointer  Smart Tilt Pointer  True      True           1.144  14.000  two-sided    0.272   0.457     0.322
# Condition   Smart Rotate Pointer  Smart Trackball     True      True           3.257  14.000  two-sided    0.006   8.824     1.222
# Condition   Smart Rotate Pointer  Smart Trackpad      True      True           2.599  14.000  two-sided    0.021   3.045     0.949
# Condition   Smart Tilt Pointer    Smart Trackball     True      True           2.884  14.000  two-sided    0.012   4.792     1.073
# Condition   Smart Tilt Pointer    Smart Trackpad      True      True           1.974  14.000  two-sided    0.068   1.209     0.736
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-15Task1Data.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l"])
data = data.groupby(['Participant', 'Condition'], as_index=False).agg({'Euclidean_distance_error': 'mean'})
ph_dist = pg.pairwise_ttests(dv='Euclidean_distance_error', within='Condition', subject='Participant', data=data)
pg.print_table(ph_dist)
# Out:
# ...
# POST HOC TESTS
# ...
#
# Contrast    A                     B                   Paired    Parametric         T     dof  Tail         p-unc    BF10    hedges
# ----------  --------------------  ------------------  --------  ------------  ------  ------  ---------  -------  ------  --------
# Condition   Smart Rotate Pointer  Smart Tilt Pointer  True      True          -0.022  14.000  two-sided    0.983   0.262    -0.006
# Condition   Smart Rotate Pointer  Smart Trackball     True      True           3.757  14.000  two-sided    0.002  20.345     1.126
# Condition   Smart Rotate Pointer  Smart Trackpad      True      True           1.629  14.000  two-sided    0.126   0.772     0.531
# Condition   Smart Tilt Pointer    Smart Trackball     True      True           2.544  14.000  two-sided    0.023   2.796     0.872
# Condition   Smart Tilt Pointer    Smart Trackpad      True      True           1.137  14.000  two-sided    0.275   0.455     0.429
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-P15Task1_BigTargets.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l"])
data = data.groupby(['Participant','Condition'], as_index=False).agg({'Error_count':'mean'})
#print(data)
#data_error_B=data.loc[(data['Target Area']>6394.94401)]
#data_error_S=data.loc[(data['Target Area']<=6394.94401)]
#print(data_error_S)
#data_error_B=data.loc[(data['Error_count']>0)]
#data_error_S=data.loc[(data['Target Area']<=6394.94401)]
ph_err_big = pg.pairwise_ttests(dv='Error_count', within='Condition', subject='Participant', data=data)
pg.print_table(ph_err_big)

# ph_err_small = pg.pairwise_ttests(dv='Error_count', within='Condition', subject='Participant', data=data)
# pg.print_table(ph_err_small)
# Out:
# ...
# POST HOC TESTS
# ...
#
# Contrast    A                     B                   Paired    Parametric         T     dof  Tail         p-unc    BF10    hedges
# ----------  --------------------  ------------------  --------  ------------  ------  ------  ---------  -------  ------  --------
# Condition   Smart Rotate Pointer  Smart Tilt Pointer  True      True           2.978  14.000  two-sided    0.010   5.576     0.564
# Condition   Smart Rotate Pointer  Smart Trackball     True      True           2.636  14.000  two-sided    0.020   3.227     1.018
# Condition   Smart Rotate Pointer  Smart Trackpad      True      True           2.240  14.000  two-sided    0.042   1.765     0.730
# Condition   Smart Tilt Pointer    Smart Trackball     True      True           1.201  14.000  two-sided    0.250   0.483     0.480
# Condition   Smart Tilt Pointer    Smart Trackpad      True      True           0.458  14.000  two-sided    0.654   0.288     0.143
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import seaborn as sns

# Read experiment data into a data frame
data = pd.read_csv("P1-P15Task1_SmallTargets.csv")

# Get rid of excess columns - we don't need these for this analysis
data = data.drop(columns=["Block","Task", "Target.x", "Target.y", "Targetsize.b","Targetsize.l"])
data = data.groupby(['Participant','Condition'], as_index=False).agg({'Error_count':'mean'})
#print(data)
#data_error_B=data.loc[(data['Target Area']>6394.94401)]
#data_error_S=data.loc[(data['Target Area']<=6394.94401)]
#print(data_error_S)
#data_error_B=data.loc[(data['Error_count']>0)]
#data_error_S=data.loc[(data['Target Area']<=6394.94401)]
ph_err_small = pg.pairwise_ttests(dv='Error_count', within='Condition', subject='Participant', data=data)
pg.print_table(ph_err_small)
# Out:
# ...
# POST HOC TESTS
# ...
#
# Contrast    A                     B                   Paired    Parametric         T     dof  Tail         p-unc    BF10    hedges
# ----------  --------------------  ------------------  --------  ------------  ------  ------  ---------  -------  ------  --------
# Condition   Smart Rotate Pointer  Smart Tilt Pointer  True      True           0.412  14.000  two-sided    0.686   0.283     0.140
# Condition   Smart Rotate Pointer  Smart Trackball     True      True           4.144  14.000  two-sided    0.001  38.965     1.145
# Condition   Smart Rotate Pointer  Smart Trackpad      True      True           2.402  14.000  two-sided    0.031   2.248     0.939
# Condition   Smart Tilt Pointer    Smart Trackball     True      True           2.511  14.000  two-sided    0.025   2.656     0.989
# Condition   Smart Tilt Pointer    Smart Trackpad      True      True           2.213  14.000  two-sided    0.044   1.697     0.779
# ...
